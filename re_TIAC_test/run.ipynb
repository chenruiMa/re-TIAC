# %%
# %run main.py
# Out:
# Namespace(abs_num_heads=10, batch_size=1024, beta=0.02, dataset='Beauty', device='cuda:1', dropout_rate=0.5, gcn_layer=4, hidden_units=50, inference_only=False, l2_emb=0.0001, lr=0.0001, maxlen=20, num_blocks=2, num_epochs=501, num_heads=10, state_dict_path=None, train_dir='default')
# data processing done...
# /home/machery/Untitled Folder/re_TIAC_test/utils.py:136: RuntimeWarning: divide by zero encountered in power
#   d_inv = np.power(rowsum, -1).flatten()
# time interval processing done...
# generate single-normalized adjacency matrix.
# generate single-normalized adjacency matrix.
# generate single-normalized adjacency matrix.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/Untitled Folder/re_TIAC_test/main.py in <module>
#     198
#     199 if __name__ == '__main__':
# --> 200     main()
#     201
#
# ~/Untitled Folder/re_TIAC_test/main.py in main()
# ...

# %% [markdown]
# 现有数据集下（Beauty-10000）按照TIAC进行实验结果。
# max NDCG is 0.3438169764209245, max HR is 0.5332 max MRR is 0.28503809523809565
#
# 现有数据集下（Beauty-全部用户）按照TIAC进行实验结果。
# max NDCG is 0.34294806852597387, max HR is 0.5298484103206189 max MRR is 0.2850932733987304
#
# 仅使用训练数据进行构图（或许这样才是正确的？）
# max NDCG is 0.3280325312749606, max HR is 0.5083 max MRR is 0.2720677777777784
